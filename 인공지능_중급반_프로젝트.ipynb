# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoSangHyeok/ai-intermediate-project/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_%EC%A4%91%EA%B8%89%EB%B0%98_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 한글 폰트 설치
# !apt install fonts-nanum -y

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
plt.rc('font', family='NanumBarunGothic')
matplotlib.font_manager._rebuild()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
# 라이브러리 설치
# !git clone https://github.com/ndb796/bing_image_downloader
# Out:
# Cloning into 'bing_image_downloader'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 86 (delta 38), reused 46 (delta 16), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './custom_dataset/train/',
    './custom_dataset/test/',
]

# 초기 디렉토리 생성
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# 수집한 이미지를 학습, 평가 데이터로 구분
def dataset_split(query, train_cnt):
    # 학습 및 평가 데이터셋 디렉토리 만들기
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # 학습 및 평가 데이터셋 준비
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './custom_dataset/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
query = '딸기'
downloader.download(query, limit=50,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 40)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 50 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://cdn.wadiz.kr/ft/images/green001/2019/1201/20191201093511904_50.jpg/wadiz/format/jpg/quality/80/optimize)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://shop.biumfood.com/upload/images/20191203115026_374002.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (http://cfile238.uf.daum.net/image/025F7D3351638B4224D3A6)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (http://image14.hanatour.com/uploads/2015/07/IMG-6.jpg)
# #4 파일 다운로드가 완료되었습니다.
# #5 이미지 다운로드 (https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FdoDl8w%2FbtqRt54lGIg%2FUWxP9Jong94b2FiMrH4lDK%2Fimg.jpg)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FdoDl8w%2FbtqRt54lGIg%2FUWxP9Jong94b2FiMrH4lDK%2Fimg.jpg
# [Error] HTTP Error 403: Forbidden
# #5 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/27396B4F54C1CBB808)
# #5 파일 다운로드가 완료되었습니다.
# #6 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F1625EA574DC7893208)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F1625EA574DC7893208
# [Error] HTTP Error 403: Forbidden
# #6 이미지 다운로드 (http://www.hubaskorea.com/data/file/hubas0402/data_board2_니콘_001.jpg)
# [Info] Issue getting: http://www.hubaskorea.com/data/file/hubas0402/data_board2_니콘_001.jpg
# [Error] 'ascii' codec can't encode characters in position 37-38: ordinal not in range(128)
# #6 이미지 다운로드 (http://user-generated.around.so/pictures/zyDA0OO82B)
# #6 파일 다운로드가 완료되었습니다.
# #7 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F212FE54A53A5A40A21)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F212FE54A53A5A40A21
# [Error] HTTP Error 403: Forbidden
# #7 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D223395A796DB813)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D223395A796DB813
# [Error] HTTP Error 403: Forbidden
# #7 이미지 다운로드 (http://image.idus.com/image/files/45fdf3a9a30b43bc970e97437996dbf0.jpg)
# #7 파일 다운로드가 완료되었습니다.
# #8 이미지 다운로드 (https://img.insight.co.kr/static/2017/10/27/2000/3q84utu7734p1rlsr161.jpg)
# #8 파일 다운로드가 완료되었습니다.
# #9 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D454465DE435F811)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D454465DE435F811
# [Error] HTTP Error 403: Forbidden
# #9 이미지 다운로드 (https://i1.wp.com/sharehows.com/wp-content/uploads/2017/03/strawberry_01.jpg?fit=800%2C533)
# #9 파일 다운로드가 완료되었습니다.
# #10 이미지 다운로드 (http://gdimg1.gmarket.co.kr/goods_image2/exlarge_moreimg/884/341/884341056/884341056_00.jpg?ver=1513541060)
# #10 파일 다운로드가 완료되었습니다.
# #11 이미지 다운로드 

# #36 파일 다운로드가 완료되었습니다.
# #37 이미지 다운로드 (http://cfs11.blog.daum.net/original/6/blog/2008/04/05/08/16/47f6b6e3ac91b&amp;filename=IMG_3913.JPG)
# #37 파일 다운로드가 완료되었습니다.
# #38 이미지 다운로드 (http://cfile221.uf.daum.net/image/153D693F4F8F744E015B8B)
# #38 파일 다운로드가 완료되었습니다.
# #39 이미지 다운로드 (https://2.gall-img.com/hygall/files/attach/images/82/246/625/326/9eab07cae2d3e42d957320d7df434331.jpg)
# #39 파일 다운로드가 완료되었습니다.
# [Info] Done. Downloaded 39 images.
# [Info] Indexing page: 2
# [Info] Indexed 35 Images on Page 2.
# ===============================================
# #40 이미지 다운로드 (https://cdn.wadiz.kr/ft/images/green001/2019/1201/20191201093511904_50.jpg/wadiz/format/jpg/quality/80/optimize)
# #40 파일 다운로드가 완료되었습니다.
# #41 이미지 다운로드 (https://shop.biumfood.com/upload/images/20191203115026_374002.jpg)
# #41 파일 다운로드가 완료되었습니다.
# #42 이미지 다운로드 (http://cfile238.uf.daum.net/image/025F7D3351638B4224D3A6)
# #42 파일 다운로드가 완료되었습니다.
# #43 이미지 다운로드 (http://image14.hanatour.com/uploads/2015/07/IMG-6.jpg)
# #43 파일 다운로드가 완료되었습니다.
# #44 이미지 다운로드 (https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FdoDl8w%2FbtqRt54lGIg%2FUWxP9Jong94b2FiMrH4lDK%2Fimg.jpg)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&amp;fname=https:%2F%2Fblog.kakaocdn.net%2Fdn%2FdoDl8w%2FbtqRt54lGIg%2FUWxP9Jong94b2FiMrH4lDK%2Fimg.jpg
# [Error] HTTP Error 403: Forbidden
# #44 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/27396B4F54C1CBB808)
# #44 파일 다운로드가 완료되었습니다.
# #45 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F1625EA574DC7893208)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F1625EA574DC7893208
# [Error] HTTP Error 403: Forbidden
# #45 이미지 다운로드 (http://www.hubaskorea.com/data/file/hubas0402/data_board2_니콘_001.jpg)
# [Info] Issue getting: http://www.hubaskorea.com/data/file/hubas0402/data_board2_니콘_001.jpg
# [Error] 'ascii' codec can't encode characters in position 37-38: ordinal not in range(128)
# #45 이미지 다운로드 (http://user-generated.around.so/pictures/zyDA0OO82B)
# #45 파일 다운로드가 완료되었습니다.
# #46 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F212FE54A53A5A40A21)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F212FE54A53A5A40A21
# [Error] HTTP Error 403: Forbidden
# #46 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D223395A796DB813)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D223395A796DB813
# [Error] HTTP Error 403: Forbidden
# #46 이미지 다운로드 (http://image.idus.com/image/files/45fdf3a9a30b43bc970e97437996dbf0.jpg)
# #46 파일 다운로드가 완료되었습니다.
# #47 이미지 다운로드 (https://img.insight.co.kr/static/2017/10/27/2000/3q84utu7734p1rlsr161.jpg)
# #47 파일 다운로드가 완료되었습니다.
# #48 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D454465DE435F811)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99D454465DE435F811
# [Error] HTTP Error 403: Forbidden
# #48 이미지 다운로드 (https://i1.wp.com/sharehows.com/wp-content/uploads/2017/03/strawberry_01.jpg?fit=800%2C533)
# #48 파일 다운로드가 완료되었습니다.
# #49 이미지 다운로드 (http://gdimg1.gmarket.co.kr/goods_image2/exlarge_moreimg/884/341/884341056/884341056_00.jpg?ver=1513541060)
# #49 파일 다운로드가 완료되었습니다.
# #50 이미지 다운로드 (http://cfs13.blog.daum.net/image/21/blog/2008/01/13/15/34/4789b0e9afd48)
# #50 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 50 images.
# [Train Dataset] image_43.jpg
# [Train Dataset] image_17.jpg
# [Train Dataset] image_46.jpg
# [Train Dataset] image_44.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_49.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_45.jpg
# [Train Dataset] image_9.jpg
# [Train Dataset] image_41.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_42.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_12.JPG
# [Train Dataset] image_7.jpg
# [Train Dataset] image_36.png
# [Train Dataset] image_5.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_14.jpg
# [Train Dataset] image

# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F99D2BA495D529A8E34
# [Error] HTTP Error 403: Forbidden
# #44 이미지 다운로드 (http://cfile239.uf.daum.net/image/995B36335A12B2990D6C4F)
# #44 파일 다운로드가 완료되었습니다.
# #45 이미지 다운로드 (https://t1.daumcdn.net/thumb/R1280x0/?fname=http://t1.daumcdn.net/brunch/service/user/2vLY/image/XNDn8k0q6NW4OFk8kS1I_E52TgQ.jpg)
# #45 파일 다운로드가 완료되었습니다.
# #46 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2255C7345746866216)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2255C7345746866216
# [Error] HTTP Error 403: Forbidden
# #46 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/26211E4C5451CF0924)
# #46 파일 다운로드가 완료되었습니다.
# #47 이미지 다운로드 (https://launchdog.kr/link/441188)
# #47 파일 다운로드가 완료되었습니다.
# #48 이미지 다운로드 (http://cfile213.uf.daum.net/image/17160F4B4EC9A84924FFCE)
# #48 파일 다운로드가 완료되었습니다.
# #49 이미지 다운로드 (https://yt3.ggpht.com/a/AGF-l79aUi490nW_8tzQIQU2Jq6SXKSmkctDNUCszA=s900-c-k-c0xffffffff-no-rj-mo)
# #49 파일 다운로드가 완료되었습니다.
# #50 이미지 다운로드 (http://cfile229.uf.daum.net/image/2344854155F33935258263)
# #50 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 50 images.
# [Train Dataset] image_43.jpg
# [Train Dataset] image_17.jpg
# [Train Dataset] image_23.jpeg
# [Train Dataset] image_46.jpg
# [Train Dataset] image_44.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_19.JPG
# [Train Dataset] image_27.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_49.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_45.jpg
# [Train Dataset] image_9.jpg
# [Train Dataset] image_41.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_42.jpg
# [Train Dataset] image_1.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_7.jpg
# [Train Dataset] image_5.jpg
# [Train Dataset] image_4.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_14.jpg
# [Train Dataset] image_48.jpg
# [Train Dataset] image_35.jpg
# [Train Dataset] image_6.jpg
# [Train Dataset] image_3.jpg
# [Train Dataset] image_32.jpg
# [Train Dataset] image_38.jpg
# [Train Dataset] image_50.jpg
# [Train Dataset] image_13.jpg
# [Train Dataset] image_8.jpg
# [Train Dataset] image_15.jpg
# [Train Dataset] image_2.jpg
# [Test Dataset] image_24.jpg
# [Test Dataset] image_36.jpg
# [Test Dataset] image_34.jpg
# [Test Dataset] image_28.jpg
# [Test Dataset] image_47.jpg
# [Test Dataset] image_22.jpg
# [Test Dataset] image_33.jpeg
# [Test Dataset] image_25.jpg
# [Test Dataset] image_26.jpg
# [Test Dataset] image_18.jpg

# %%
query = '석류'
downloader.download(query, limit=50,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 40)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 50 Images on Page 1.
# ===============================================
# #1 이미지 다운로드 (https://img.lovepik.com/element/40023/7990.png_1200.png)
# #1 파일 다운로드가 완료되었습니다.
# #2 이미지 다운로드 (https://health.chosun.com/site/data/img_dir/2020/06/04/2020060402692_0.jpg)
# [Info] Issue getting: https://health.chosun.com/site/data/img_dir/2020/06/04/2020060402692_0.jpg
# [Error] <urlopen error timed out>
# #2 이미지 다운로드 (http://www.inztimes.com/wp-content/uploads/2017/11/석류4.png)
# [Info] Issue getting: http://www.inztimes.com/wp-content/uploads/2017/11/석류4.png
# [Error] 'ascii' codec can't encode characters in position 32-33: ordinal not in range(128)
# #2 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F27649E3357ACA96717)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F27649E3357ACA96717
# [Error] HTTP Error 403: Forbidden
# #2 이미지 다운로드 (http://www.fmnews.kr/files/attach/newsphoto/18497/fb0ac50efb40db5025053870f096c314.jpg)
# #2 파일 다운로드가 완료되었습니다.
# #3 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2303D934587FF6D413)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2303D934587FF6D413
# [Error] HTTP Error 403: Forbidden
# #3 이미지 다운로드 (https://img.research-paper.co.kr/resources/2018/10/23/AXPhjvTAEmgkTvZr.jpg)
# [Info] Issue getting: https://img.research-paper.co.kr/resources/2018/10/23/AXPhjvTAEmgkTvZr.jpg
# [Error] <urlopen error [Errno 111] Connection refused>
# #3 이미지 다운로드 (http://image.auction.co.kr/itemimage/17/04/c5/1704c569b6.jpg)
# #3 파일 다운로드가 완료되었습니다.
# #4 이미지 다운로드 (https

# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F023BB941515AE6DE2F
# [Error] HTTP Error 403: Forbidden
# #40 이미지 다운로드 (http://cfile221.uf.daum.net/image/2518B1435275844C26AB43)
# #40 파일 다운로드가 완료되었습니다.
# #41 이미지 다운로드 (http://www.polinews.co.kr/data/photos/20190417/art_15562707917767_ed5ced.png)
# #41 파일 다운로드가 완료되었습니다.
# #42 이미지 다운로드 (http://ecomedia.co.kr/news/data/20200626/p1065588203116334_900_thum.jpg)
# #42 파일 다운로드가 완료되었습니다.
# #43 이미지 다운로드 (https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory&amp;fname=http:%2F%2Fcfile7.uf.tistory.com%2Fimage%2F024ED444519EF01B3669BF)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R720x0.q80/?scode=mtistory&amp;fname=http:%2F%2Fcfile7.uf.tistory.com%2Fimage%2F024ED444519EF01B3669BF
# [Error] HTTP Error 403: Forbidden
# #43 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2653643E566B225930)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F2653643E566B225930
# [Error] HTTP Error 403: Forbidden
# #43 이미지 다운로드 (https://img.lovepik.com/element/40022/1060.png_860.png)
# #43 파일 다운로드가 완료되었습니다.
# #44 이미지 다운로드 (https://t1.daumcdn.net/cfile/tistory/2533E63C57B5948824)
# #44 파일 다운로드가 완료되었습니다.
# #45 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F996650425D5BE32825)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F996650425D5BE32825
# [Error] HTTP Error 403: Forbidden
# #45 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9963AF475BCE5ADA03)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F9963AF475BCE5ADA03
# [Error] HTTP Error 403: Forbidden
# #45 이미지 다운로드 (http://pds24.egloos.com/pds/201207/29/16/b0140416_50151478cbb9c.jpg)
# #45 파일 다운로드가 완료되었습니다.
# #46 이미지 다운로드 (https://1.bp.blogspot.com/-g0kxlP_b-3o/VHb0TgkxcqI/AAAAAAAAEGA/0nHYxJyFIU8/s1600/2014.11.27%2B오호리%2B마이즈루공원%2B002.JPG)
# [Info] Issue getting: https://1.bp.blogspot.com/-g0kxlP_b-3o/VHb0TgkxcqI/AAAAAAAAEGA/0nHYxJyFIU8/s1600/2014.11.27%2B오호리%2B마이즈루공원%2B002.JPG
# [Error] 'ascii' codec can't encode characters in position 73-75: ordinal not in range(128)
# #46 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/1938E4264AC376C90F)
# #46 파일 다운로드가 완료되었습니다.
# #47 이미지 다운로드 (https://img.lovepik.com/element/40023/8245.png_860.png)
# #47 파일 다운로드가 완료되었습니다.
# #48 이미지 다운로드 (https://img.lovepik.com/element/40035/6507.png_860.png)
# #48 파일 다운로드가 완료되었습니다.
# #49 이미지 다운로드 (https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F2636AF4E55F1F12F1E)
# [Info] Issue getting: https://img1.daumcdn.net/thumb/R800x0/?scode=mtistory2&amp;fname=https:%2F%2Ft1.daumcdn.net%2Fcfile%2Fblog%2F2636AF4E55F1F12F1E
# [Error] HTTP Error 403: Forbidden
# #49 이미지 다운로드 (http://cfile216.uf.daum.net/image/261D7349545982B019AADB)
# #49 파일 다운로드가 완료되었습니다.
# #50 이미지 다운로드 (https://t1.daumcdn.net/cfile/blog/2314D1415271A35917)
# #50 파일 다운로드가 완료되었습니다.
# ===============================================
# [Info] Done. Downloaded 50 images.
# [Train Dataset] image_17.jpg
# [Train Dataset] image_46.jpg
# [Train Dataset] image_44.jpg
# [Train Dataset] image_12.jpg
# [Train Dataset] image_16.jpg
# [Train Dataset] image_27.jpg
# [Train Dataset] image_31.jpg
# [Train Dataset] image_49.jpg
# [Train Dataset] image_39.jpg
# [Train Dataset] image_9.png
# [Train Dataset] image_45.jpg
# [Train Dataset] image_11.jpg
# [Train Dataset] image_7.png
# [Train Dataset] image_42.jpg
# [Train Dataset] image_30.jpg
# [Train Dataset] image_21.jpg
# [Train Dataset] image_40.jpg
# [Train Dataset] image_14.png
# [Train Dataset] image_1.png
# [Train Dataset] image_48.png
# [Train Dataset] image_5.jpg
# [Train Dataset] image_35.png
# [Train Dataset] image_4.jpg
# [Train Dataset] image_10.jpg
# [Train Dataset] image_20.jpg
# [Train Dataset] image_23.jpg
# [Train Dataset] image_37.jpg
# [Train Dataset] image_33.jpg
# [Train Dataset] image_29.jpg
# [Train Dataset] image_6.jpg
# [Train Dataset] image_3.jpg
# [Train Dataset] image_13.png
# [Train Dataset] image_32.jpg
# [Train Dataset] image_38.jpg
# [Train Dataset] image_50.jpg
# [Train Dataset] image_19.jpg
# [Train Dataset] image_41.png
# [Train Dataset] image_8.jpg
# [Train Dataset] image_15.jpg
# [Train Dataset] image_2.jpg
# [Test Dataset] image_24.jpg
# [Test Dataset] image_36.jpg
# [Test Dataset] image_43.png
# [Test Dataset] image_34.jpg
# [Test Dataset] image_28.jpg
# [Test Dataset] image_47.png
# [Test Dataset] image_22.jpg
# [Test Dataset] image_25.jpg
# [Test Dataset] image_26.jpg
# [Test Dataset] image_18.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device 객체

# %%
# 데이터셋을 불러올 때 사용할 변형 객체 정의
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # 데이터 증진(augmentation)
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # 정규화(normalization)
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './custom_dataset'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('학습 데이터셋 크기:', len(train_datasets))
print('테스트 데이터셋 크기:', len(test_datasets))

class_names = train_datasets.classes
print('클래스:', class_names)
# Out:
# 학습 데이터셋 크기: 120
# 테스트 데이터셋 크기: 30
# 클래스: ['딸기', '사과', '석류']
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
def imshow(input, title):
    # torch.Tensor를 numpy 객체로 변환
    input = input.numpy().transpose((1, 2, 0))
    # 이미지 정규화 해제
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # 이미지 출력
    plt.imshow(input)
    plt.title(title)
    plt.show()


# 학습 데이터를 배치 단위로 불러오기
iterator = iter(train_dataloader)

# 현재 배치를 이용해 격자 형태의 이미지를 만들어 시각화
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# 전이 학습(transfer learning): 모델의 출력 뉴런 수를 3개로 교체하여 마지막 레이어 다시 학습
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
num_epochs = 30
model.train()
start_time = time.time()

# 전체 반복(epoch) 수 만큼 반복
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # 배치 단위로 학습 데이터 불러오기
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        # 모델에 입력(forward)하고 결과 계산
        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # 역전파를 통해 기울기(gradient) 계산 및 학습 진행
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # 학습 과정 중에 결과 출력
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# #0 Loss: 0.7979 Acc: 65.0000% Time: 5.6109s
# #1 Loss: 0.3144 Acc: 90.0000% Time: 10.7799s
# #2 Loss: 0.5079 Acc: 77.5000% Time: 16.0606s
# #3 Loss: 0.4654 Acc: 82.5000% Time: 21.6896s
# #4 Loss: 0.6886 Acc: 76.6667% Time: 27.0495s
# #5 Loss: 0.2330 Acc: 91.6667% Time: 32.5581s
# #6 Loss: 0.1967 Acc: 90.8333% Time: 38.0861s
# #7 Loss: 0.1724 Acc: 92.5000% Time: 43.5642s
# #8 Loss: 0.1880 Acc: 92.5000% Time: 48.8088s
# #9 Loss: 0.3215 Acc: 88.3333% Time: 54.3796s
# #10 Loss: 0.4379 Acc: 87.5000% Time: 60.1454s
# #11 Loss: 0.4698 Acc: 85.0000% Time: 65.5019s
# #12 Loss: 0.2387 Acc: 93.3333% Time: 70.7971s
# #13 Loss: 0.1147 Acc: 95.8333% Time: 76.1123s
# #14 Loss: 0.1989 Acc: 91.6667% Time: 81.4359s
# #15 Loss: 0.3324 Acc: 88.3333% Time: 86.5827s
# #16 Loss: 0.0679 Acc: 97.5000% Time: 92.1603s
# #17 Loss: 0.1047 Acc: 95.0000% Time: 97.4026s
# #18 Loss: 0.1609 Acc: 93.3333% Time: 102.8785s
# #19 Loss: 0.1212 Acc: 96.6667% Time: 108.1367s
# #20 Loss: 0.3887 Acc: 90.8333% Time: 113.5146s
# #21 Loss: 0.0592 Acc: 98.3333% Time: 119.1062s
# #22 Loss: 0.0966 Acc: 95.8333% Time: 124.5048s
# #23 Loss: 0.0295 Acc: 99.1667% Time: 130.1542s
# #24 Loss: 0.0355 Acc: 99.1667% Time: 135.2882s
# #25 Loss: 0.0460 Acc: 99.1667% Time: 140.4352s
# #26 Loss: 0.1464 Acc: 95.8333% Time: 145.8198s
# #27 Loss: 0.1085 Acc: 95.8333% Time: 151.2901s
# #28 Loss: 0.0696 Acc: 96.6667% Time: 156.6127s
# #29 Loss: 0.0519 Acc: 97.5000% Time: 161.9287s

# %%
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # 한 배치의 첫 번째 이미지에 대하여 결과 시각화
        print(f'[예측 결과: {class_names[preds[0]]}] (실제 정답: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: 석류] (실제 정답: 석류)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: 석류] (실제 정답: 석류)
# [예측 결과: 석류] (실제 정답: 석류)
# [예측 결과: 사과] (실제 정답: 사과)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [예측 결과: 딸기] (실제 정답: 딸기)
# [Test Phase] Loss: 0.3559 Acc: 93.3333% Time: 3.0688s

# %%
# 테스트용 이미지 다운로드하기
# !wget https://www.artinsight.co.kr/data/tmp/2005/20200508224015_fxvmwrnb.jpg -O test_image.jpg
# Out:
# --2021-11-04 17:55:18--  https://www.artinsight.co.kr/data/tmp/2005/20200508224015_fxvmwrnb.jpg
# Resolving www.artinsight.co.kr (www.artinsight.co.kr)... 115.68.52.47
# Connecting to www.artinsight.co.kr (www.artinsight.co.kr)|115.68.52.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59220 (58K) [image/jpeg]
# Saving to: ‘test_image.jpg’
#
# test_image.jpg      100%[===================>]  57.83K  --.-KB/s    in 0.09s
#
# 2021-11-04 17:55:21 (668 KB/s) - ‘test_image.jpg’ saved [59220/59220]

# %%
from PIL import Image


image = Image.open('test_image.jpg')
image = transforms_test(image).unsqueeze(0).to(device)

with torch.no_grad():
    outputs = model(image)
    _, preds = torch.max(outputs, 1)
    imshow(image.cpu().data[0], title='예측 결과: ' + class_names[preds[0]])
